# %%
# Paired Student's t-test
import pandas as pd
from scipy.stats import ttest_rel
import numpy as np

def readRes(filename, cond=False):
    if cond:
        return pd.read_csv(filename, sep="\t", names=["fold","qid", "score"])
    return pd.read_csv(filename, sep="\t", names=["fold","qid", "score"])

# %%
metricKeys = {"%s@%d" % (i, j): [] for i in ["r", "ndcg", "nerr"] for j in [10]}
metricKeys["rp"] = []

# metricKeys["mrr"] = []
# metricKeys["map"] = []

for key in metricKeys:
#     Query + Property
    data1 = readRes("out/r/akgg-r_ms_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_44.%s" % key)
    data1 = readRes("out/r/akgg-r_vanilla_bert_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_44.%s" % key)
#     data1 = readRes("out/r/akgg-r_cedr_pacrr_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_50.%s" % key)
#     data1 = readRes("out/r/akgg-r_cedr_drmm_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_45.%s" % key)
#     data1 = readRes("out/r/akgg-r_sbert_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_53_16.%s" % key)
#     data2 = readRes("out/r/akgg-r_crossbert2_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_19.%s" % key)
    data2 = readRes("out/r/akgg-r_cedr_knrm_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_45.%s" % key)
# 
#   Wikipedia
    data1 = readRes("out/r/akgg-r_ms_m2_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_19_06_21_01.%s" % key)
#     data1 = readRes("out/r/akgg-r_mulbert_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_45_56.%s" % key)
#     data1 = readRes("out/r/akgg-r_mul_cedr_knrm_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_19_14_37_10.%s" % key)
#     data1 = readRes("out/r/akgg-r_mul_cedr_pacrr_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_19_14_37_10.%s" % key)
#     data1 = readRes("out/r/akgg-r_mul_cedr_drmm_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_19_14_37_10.%s" % key)
    data2 = readRes("out/r/akgg-r_crossbert2_m2_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_19.%s" % key)

    
#     print(len(data1), len(data2))
    
    print(key, ttest_rel(np.array(data1["score"].tolist()), np.array(data2["score"].tolist())), np.mean(data1["score"].tolist()), np.mean(data2["score"].tolist()))
# Out:
# r@10 Ttest_relResult(statistic=-0.662166047353021, pvalue=0.5085335431055553) 0.5182205938864629 0.5222821441048036
# ndcg@10 Ttest_relResult(statistic=-1.8631825764684813, pvalue=0.0637224421288314) 0.6462998165938865 0.6628663187772926
# nerr@10 Ttest_relResult(statistic=-1.2364157247006107, pvalue=0.21757623280878732) 0.7068301004366813 0.7251238427947598
# rp Ttest_relResult(statistic=-0.28447396253884266, pvalue=0.776305385007608) 0.7493605240174673 0.7514947336244541

# %%
metricKeys = {"%s@%d" % (i, j): [] for i in ["r", "ndcg", "nerr"] for j in [10]}
metricKeys["rp"] = []
# metricKeys["mrr"] = []
# metricKeys["map"] = []

for key in metricKeys:
#     Query + Property
    data1 = readRes("out/10/eai_ms_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_22_23_59.%s" % key)
    data1 = readRes("out/10/eai_sbert_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_18_14_21_44.%s" % key)
    data1 = readRes("out/10/eai_vanilla_bert_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_21_19_35.%s" % key)
#     data1 = readRes("out/10/eai_cedr_pacrr_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_22_24_03.%s" % key)
#     data1 = readRes("out/10/eai_cedr_knrm_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_22_23_58.%s" % key)
#     data1 = readRes("out/10/eai_cedr_drmm_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_22_23_59.%s" % key)
    data2 = readRes("out/10/dynamic/eai_crossbert2_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_23_49_31.%s" % key)
#   Wikipedia
    data1 = readRes("out/10/eai_ms_m2_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_18_11_48_11.%s" % key)
#     data1 = readRes("out/10/eai_mulbert_m2_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_18_12_44_35.%s" % key)
#     data1 = readRes("out/10/eai_mul_cedr_knrm_m1_ml16_eai-wikipedia_eai-question-qq_all_e20_es1_2020_02_19_14_38_00.%s" % key)
#     data1 = readRes("out/10/eai_mul_cedr_drmm_m1_ml16_eai-wikipedia_eai-question-qq_all_e20_es1_2020_02_19_14_38_00.%s" % key)
#     data1 = readRes("out/10/eai_mul_cedr_pacrr_m1_ml16_eai-wikipedia_eai-question-qq_all_e20_es1_2020_02_19_14_38_00.%s" % key)
#     data1 = readRes("out/10/eai_sbert_m2_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_18_14_21_54.%s" % key)
    data2 = readRes("out/10/dynamic/eai_crossbert2_m2_ml16_eai-wikihow_eai-question-qq_all_e10_es1_2020_02_18_08_13_00.%s" % key)

    
#     print(len(data1), len(data2))
    
    print(key, ttest_rel(np.array(data1["score"].tolist()), np.array(data2["score"].tolist())), np.mean(data1["score"].tolist()), np.mean(data2["score"].tolist()))
# Out:
# r@10 Ttest_relResult(statistic=-4.178053390550543, pvalue=4.742225146550771e-05) 0.6775453353293412 0.7851640898203592
# ndcg@10 Ttest_relResult(statistic=-2.285446007065749, pvalue=0.023551733309221674) 0.5861269700598802 0.6447543233532934
# nerr@10 Ttest_relResult(statistic=-1.443192796058447, pvalue=0.15085057677256972) 0.5671715748502993 0.609519868263473
# rp Ttest_relResult(statistic=-0.21519715834751618, pvalue=0.8298777693789157) 0.4548763832335329 0.46260918562874254

# %%
categories = ["action", "creativework", "intangible", "medicalentity", "organization", "person", "place"]
for i in categories:
    print(i, df[df.entityType.str.contains(i)].query_id.nunique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7fe9579d3d26> in <module>
#       1 categories = ["action", "creativework", "intangible", "medicalentity", "organization", "person", "place"]
#       2 for i in categories:
# ----> 3     print(i, df[df.entityType.str.contains(i)].query_id.nunique())
#
# NameError: name 'df' is not defined

# %%
doc = pd.read_csv("data/cedr/doc.tsv", sep="\t", names=["d", "did", "dtext"])
query = pd.read_csv("data/cedr/query.tsv", sep="\t", names=["q", "qid", "query"])
def readPrediction(filename, name):
    df_run =  pd.read_csv(filename, sep="\t", names=["fold","qid", "did", "score"])
    df_run = df_run.merge(query, how="left", on="qid")
    df_run = df_run.merge(doc, how="left", on="did")
#     print(df_run['dtext'])
    return df_run.groupby(["fold", "query"])["dtext"].apply(list).reset_index(name=name)
#     data1 = readRes("out/r/akgg-r_mul_cedr_knrm_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_19_14_37_10.%s" % key)

ms = readPrediction("out/r/akgg-r_ms_m2_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_19_06_21_01.out", "MS")
bert = readPrediction("out/r/akgg-r_mul_cedr_knrm_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_19_14_37_10.out", "CEDR_KNRM")
cross = readPrediction("out/r/akgg-r_crossbert2_m2_ml16_akgg-wikihow_akgg-question-qq_all_e20_es1_2020_02_19_06_22_06.out", "CrossBERT")

# %%
msNDCG = readRes("out/r/akgg-r_ms_m2_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_19_06_21_01.ndcg@10")
bertNDCG = readRes("out/r/akgg-r_mul_cedr_knrm_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_19_14_37_10.ndcg@10")
crossNDCG = readRes("out/r/akgg-r_crossbert2_m2_ml16_akgg-wikihow_akgg-question-qq_all_e20_es1_2020_02_19_06_22_06.ndcg@10")

# %%
ms = pd.concat([ms, msNDCG["score"]], axis=1)
bert = pd.concat([bert, bertNDCG["score"]], axis=1)
cross = pd.concat([cross, crossNDCG["score"]], axis=1)

# %%
ms.columns = ['fold', 'query', 'MS', "MS_score"]
bert.columns = ['fold', 'query', 'CEDR_KNRM	', "CEDR_KNRM_score"]
cross.columns = ['fold', 'query', 'CrossBERT', "CrossBERT_score"]

# %%
ms.merge(bert, how="right", on=["fold", "query"]).merge(cross, how="right", on=["fold", "query"])
# Out:
#      fold                                              query  \
# 0       0                         all about my mother forget
# 1       0                                   baby shower give
# 2       0                        back to the future remember
# 3       0                                  benchmarking have
# 4       0                                  bodybuilding take
# 5       0                           brainstorming brainstorm
# 6       0                         braveheart love that movie
# 7       0                                chain smoking start
# 8       0                          chernobyl disaster happen
# 9       0                     formula one become a f1 driver
# 10      0                                funding get funding
# 11      0                            give me five give fives
# 12      0                         graduation attend ceremony
# 13      0            hair coloring bleach hair back to brown
# ...

# %%
eai = pd.read_csv('/Users/jarana/workspace/projects/Entity-Attribute-Identification/data/qrel.txt',names=["qid", "none", "pid", "rele_label"], sep="\t")
eai["pid"] = [i.split(":")[1].replace(">","") for i in eai.pid.tolist()]
eai = eai.drop_duplicates()

# %%
eai['category'] = [i.split("-")[0] for i in eai.qid.tolist()]

# %%
for key in ["ndcg@10"]:
#     data = readRes("out/r/akgg-r_crossbert2_m2_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_19.%s" % key)
#     data = readRes("out/r/akgg-r_mulbert_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_45_56.%s" % key)
#     data = readRes("out/r/akgg-r_ms_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_44.%s" % key)
#     data = readRes("out/r/akgg-r_crossbert2_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_19.%s" % key)
    data = readRes("out/r/akgg-r_crossbert2_m2_ml16_akgg-wikihow_akgg-question-qq_all_e20_es1_2020_02_19_06_22_06.%s" % key)
#     data = readRes("out/r/akgg-r_vanilla_bert_m1_ml16_akgg-wikipedia_akgg-question-qq_all_e20_es1_2020_02_18_21_04_44.%s" % key)

    

    categories = ["action", "creativework", "intangible", "medicalentity", "organization", "person", "place"]
    for i in categories:
        _data = data[data.qid.isin(akgg[akgg.entityType.str.contains(i)].query_id.unique().tolist())]
        print(np.mean(_data["score"].tolist()))
# Out:
# 0.5973370714285714
# 0.3582236206896553
# 0.8773177000000001
# 0.7630152173913044
# 0.6955782068965517
# 0.6681152857142858
# 0.6917307575757575

# %%
for key in ["ndcg@10"]:

    data = readRes("out/10/eai_vanilla_bert_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_21_19_35.%s" % key)
    data = readRes("out/10/dynamic/eai_crossbert2_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_23_49_31.%s" % key)
    data = readRes("out/10/dynamic/eai_crossbert2_m2_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_23_50_03.%s" % key)
    data = readRes("out/10/dynamic/eai_crossbert2_m2_ml16_eai-wikihow_eai-question-qq_all_e10_es1_2020_02_18_08_13_00.%s" % key)
#     data = readRes("out/10/eai_ms_m1_ml16_eai-wikipedia_eai-question-qq_all_e10_es1_2020_02_17_22_23_59.%s" % key)
    
    for i in ["INEX", "QALD2", "SemSearch", "TREC"]:
        _data = data[data.qid.isin(eai[eai.category.str.contains(i)].qid.unique().tolist())]
        print(np.mean(_data["score"].tolist()))
    
#     print(len(data1), len(data2))
    
#     print(key, ttest_rel(np.array(data1["score"].tolist()), np.array(data2["score"].tolist())), np.mean(data1["score"].tolist()), np.mean(data2["score"].tolist()))
# Out:
# 0.392825
# 0.7708482258064515
# 0.6741657222222224
# 0.8845904285714286

# %%
INEX 0.3087304318181818
QALD2 0.711772241935484
SemSearch 0.664130388888889
TREC 0.7397668571428572

INEX 0.28262822727272724
QALD2 0.7226036451612903
SemSearch 0.7353228333333335
TREC 0.8435104285714284
# Out:
# array(['INEX_LD', 'INEX_XER', 'QALD2_te', 'QALD2_tr', 'SemSearch_ES',
#        'SemSearch_LS', 'TREC_Entity'], dtype=object)

# %%
INEX 0.28262822727272724
QALD2 0.7226036451612903
SemSearch 0.7353228333333335
TREC 0.8435104285714284
